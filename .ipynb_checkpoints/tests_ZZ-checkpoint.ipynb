# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, HypothesisTests
include("zz_structures.jl")
include("mbsampler.jl")
# Out:
# get_clustering (generic function with 1 method)

# %%
d, Nobs = 10, 5000
pX = 1e-1
X = sprandn(d, Nobs, pX)
X[1,:] = 1
for i in 2:d 
    nzind = X[i,:].nzind
    X[i,nzind] = rand(Laplace(),length(nzind))
end
pY = 2e-4
y = rand(Binomial(1,pY),Nobs)
while sum(y) == 0 || sum(y) == Nobs y = rand(Binomial(1,pY),Nobs) end
mb_size = 50
sum(y)
# Out:
# 1

# %%
logspace(0,log(10,5000-1),60)[1:6:end]
# Out:
# 10-element Array{Float64,1}:
#     1.0
#     2.3777
#     5.65347
#    13.4423
#    31.9617
#    75.9955
#   180.695
#   429.639
#  1021.55
#  2428.95

# %%
σ02 = 1e0
prior = gaussian_prior_nh(zeros(d), σ02*ones(d));

# %%
my_ll = ll_logistic_sp(X,y);
my_model = model(my_ll, prior)
root = find_root(my_model, rand(d));

# %%
# Sub-sampling with weights and no CV

prob_het = 0.99
gs = Array{mbsampler}(d)
gs[1] = umbsampler(Nobs,mb_size)
@showprogress for i in 2:d 
    nzind = X[i,:].nzind
    weights_het = spzeros(Nobs)
    weights_het[nzind] = abs.(X[i,nzind])./sum(abs.(X[i,nzind]))
    gs[i] = spwumbsampler(Nobs, mb_size, weights_het, prob_het)
end
gs_list_noCV = mbsampler_list(d,gs);

# %%
# Sub-sampling with weights and with CV 

norm_Xj = [norm(X[:,j]) for j in 1:Nobs]
prob_het = 0.98
gs = Array{mbsampler}(d)
gs[1] = umbsampler(Nobs,mb_size)
for i in 2:d 
    nz_ind = X[i,:].nzind
    weights_het = spzeros(Nobs)
    weights_het[nz_ind] = abs.(X[i,nz_ind]).*norm_Xj[nz_ind]
    gs[i] = spwumbsampler(Nobs, mb_size, weights_het, prob_het)
end
gs_list_CV = cvmbsampler_list(my_model, gs, root, true);

# %%
# Stratified sub-sampling with weights:

cmbsamplers = Array{mbsampler}(d)
cmbsamplers[1] = umbsampler(Nobs, mb_size)
N_cluster = mb_size
        
weights = spzeros(d, Nobs)
for i in 2:d 
    nz_ind = X[i,:].nzind
    weights[i,nz_ind] = abs.(X[i,nz_ind]).*norm_Xj[nz_ind] 
    weights[i,nz_ind] /= sum(weights[i,nz_ind])
end
    
ll_pd_root_list = [partial_derivative_vec(my_model.ll, root, i, 1:Nobs) for i in 1:d]

for dim in 2:d
    N_cluster_d = min(N_cluster, length(ll_pd_root_list[dim].nzval))
    csamplers = Array{mbsampler}(N_cluster_d)
    clusters = get_clustering(N_cluster_d, ll_pd_root_list[dim].nzval)
    for i in 1:N_cluster_d
        clusters[i] =  ll_pd_root_list[dim].nzind[clusters[i]]
    end
    scp = ones(N_cluster_d)
    for (ci, c) in enumerate(clusters)
        csamplers[ci] = wumbsampler(size(c)[1], scp[ci], weights[dim,c])
    end
    cmbsamplers[dim] = spcmbsampler(csamplers, clusters, weights[dim,:])     
end
gs_list_SS = mbsampler_list(d, cmbsamplers);

# %%
A = eye(d)
opf = projopf(A, 100)
opt = maxa_opt(10^6)
outp_CV = outputscheduler(deepcopy(opf),deepcopy(opt))
bb_ll_CV = build_bound(my_model.ll, gs_list_CV)
bb_pr_CV = build_bound(my_model.pr)
mstate_CV = zz_state(d)
outp_noCV = outputscheduler(deepcopy(opf),deepcopy(opt))
bb_ll_noCV = build_bound(my_model.ll, gs_list_noCV)
bb_pr_noCV = build_bound(my_model.pr)
mstate_noCV = zz_state(d)
outp_SS = outputscheduler(deepcopy(opf),deepcopy(opt))
bb_ll_SS = build_bound(my_model.ll, gs_list_SS)
bb_pr_SS = build_bound(my_model.pr)
mstate_SS = zz_state(d)

L = 2
adapt_speed = "none"

my_zz_sampler_CV = zz_sampler_decoupled(0, gs_list_CV, bb_pr_CV, bb_ll_CV, L, adapt_speed)
ZZ_sample_decoupled(my_model, outp_CV, my_zz_sampler_CV, mstate_CV);

my_zz_sampler_noCV = zz_sampler_decoupled(0, gs_list_noCV, bb_pr_noCV, bb_ll_noCV, L, adapt_speed)
ZZ_sample_decoupled(my_model, outp_noCV, my_zz_sampler_noCV, mstate_noCV)

my_zz_sampler_SS = zz_sampler_decoupled(0, gs_list_SS, bb_pr_SS, bb_ll_SS, L, adapt_speed)
ZZ_sample_decoupled(my_model, outp_SS, my_zz_sampler_SS, mstate_SS);
# Out:
# 10% attempts in 0.27 mins
# 20% attempts in 0.53 mins
# 30% attempts in 0.79 mins
# 40% attempts in 1.06 mins
# 50% attempts in 1.32 mins
# 60% attempts in 1.59 mins
# 70% attempts in 1.86 mins
# 80% attempts in 2.12 mins
# 90% attempts in 2.39 mins
# 100% attempts in 2.65 mins
# 10% attempts in 0.15 mins
# 20% attempts in 0.31 mins
# 30% attempts in 0.46 mins
# 40% attempts in 0.61 mins
# 50% attempts in 0.76 mins
# 60% attempts in 0.91 mins
# 70% attempts in 1.06 mins
# 80% attempts in 1.21 mins
# 90% attempts in 1.36 mins
# 100% attempts in 1.51 mins
# 10% attempts in 0.21 mins
# 20% attempts in 0.42 mins
# 30% attempts in 0.63 mins
# 40% attempts in 0.84 mins
# 50% attempts in 1.06 mins
# 60% attempts in 1.27 mins
# 70% attempts in 1.48 mins
# 80% attempts in 1.69 mins
# 90% attempts in 1.9 mins
# 100% attempts in 2.11 mins

# %%
n_samples = 10^4
xi_samples_CV = extract_samples(outp_CV.opf.xi_skeleton, 
                                outp_CV.opf.bt_skeleton, 
                                outp_CV.opf.bt_skeleton[end]/n_samples,
                                "linear");
xi_samples_noCV = extract_samples(outp_noCV.opf.xi_skeleton, 
                                outp_noCV.opf.bt_skeleton, 
                                outp_noCV.opf.bt_skeleton[end]/n_samples,
                                "linear");
xi_samples_SS = extract_samples(outp_SS.opf.xi_skeleton, 
                                outp_SS.opf.bt_skeleton, 
                                outp_SS.opf.bt_skeleton[end]/n_samples,
                                "linear");

# %%
fig = figure(figsize=(15,2))
for i in 1:d 
    subplot(1,d,i)
    hist(xi_samples_CV[i,:], bins=50, density=true, alpha=0.5, label="CV")
    hist(xi_samples_noCV[i,:], bins=50, density=true, alpha=0.5, label="no CV")
    legend(ncol=2, frameon=false)
    grid(true)
end
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x200 with 10 Axes>)

# %% [raw]
# i = 3
# [OneSampleADTest(xi_samples_CV[i,:], Normal(mean(xi_samples_CV[i,:]),std(xi_samples_CV[i,:]))) for i in 1:d]

# %%
[pvalue(ExactOneSampleKSTest(xi_samples_CV[i,:], Normal(mean(xi_samples_CV[i,:]),std(xi_samples_CV[i,:]))))
    for i in 1:d]
# Out:
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# Warning: This test is inaccurate with ties
# 10-element Array{Float64,1}:
#  0.0
#  0.000373542
#  1.45572e-9
#  0.00829016
#  6.7236e-7
#  1.66143e-16
#  0.00041572
#  5.15778e-7
#  3.7428e-12
#  0.00128749

# %% [raw]
# print("Config temps for CV   : ", round.([compute_configT(my_model, xi_samples_CV, i) for i in 1:d],1), "\n")
# print("Config temps for no CV: ", round.([compute_configT(my_model, xi_samples_noCV, i) for i in 1:d],1))

# %% [markdown]
# ### Tracelots:

# %%
fig = figure(figsize=(15,15))
for i in 1:d
    subplot(d,3,3*(i-1)+1)
    plot(xi_samples_CV[i,1000:end-2])
    if i == 1 title("CV") end 
    if i<d xticks(alpha=0) end
    grid(true)
    subplot(d,3,3*(i-1)+2)
    plot(xi_samples_noCV[i,1000:end-2])
    if i == 1 title("no CV") end 
    grid(true)
    if i<d xticks(alpha=0) end
    subplot(d,3,3*(i-1)+3)
    plot(xi_samples_SS[i,1000:end-3])
    if i == 1 title("SS") end 
    grid(true)
    if i<d xticks(alpha=0) end
end
subplots_adjust(wspace=0.1, hspace=0.01)
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x1500 with 30 Axes>)
