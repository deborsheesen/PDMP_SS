# %%
using Distributions, TimeIt, ProgressMeter, PyPlot, JLD
include("mbsampler.jl")
include("temp.jl")
# Out:
# plot_acfs_all (generic function with 2 methods)

# %% [markdown]
# ### Scaling with pX:

# %%
mb_size = 1
pX_list = logspace(-2,0,8)
Nobs_list = repeat([500], length(pX_list))
attempts = repeat([10^5], length(pX_list))
cov_dist = "uniform"
n_reps = 50
varying = "pX"
include_CV, include_stratified = true, false
prior_sigma = 1e5;

# %%
start = time()
for rep in 1:n_reps 
    for i in 1:length(pX_list) 
        my_model, root = generate_model(5, Nobs_list[i], pX_list[i], cov_dist, prior_sigma) 
        run_mbsamplers(my_model, root, mb_size, attempts[i], pX_list[i], 
                       Nobs_list[i], varying, rep, cov_dist, include_CV, include_stratified)
    end
end
print("\n Total time = ", round((time()-start)/60,2), " mins")
# Out:
# Rep = 1; pX = 0.01; stratified, CV, weighted = false true true; time = 0.18 min
# Rep = 1; pX = 0.01; stratified, CV, weighted = false true false; time = 0.18 min
# Rep = 1; pX = 0.01; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 1; pX = 0.01; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 1; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 1; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 1; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 1; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 1; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 1; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 1; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 1; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 1; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 1; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 1; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 1; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 1; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.46 min
# Rep = 1; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 1; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.29 min
# Rep = 1; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 1; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.4 min
# Rep = 1; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 1; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 1; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 1; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 1; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.24 min
# Rep = 1; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.27 min
# Rep = 1; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.23 min
# Rep = 1; pX = 1.0; stratified, CV, weighted = false true true; time = 0.27 min
# Rep = 1; pX = 1.0; stratified, CV, weighted = false true false; time = 0.24 min
# Rep = 1; pX = 1.0; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 1; pX = 1.0; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 2; pX = 0.01; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 2; pX = 0.01; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 2; pX = 0.01; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 2; pX = 0.01; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 2; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 2; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 2; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 2; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 2; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 2; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 2; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.31 min
# Rep = 2; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 2; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 2; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.26 min
# Rep = 2; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 2; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 2; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 2; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.26 min
# Rep = 2; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 2; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 2; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.44 min
# Rep = 2; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 2; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.44 min
# Rep = 2; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 2; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 2; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 2; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 2; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 2; pX = 1.0; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 2; pX = 1.0; stratified, CV, weighted = false true false; time = 0.45 min
# Rep = 2; pX = 1.0; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 2; pX = 1.0; stratified, CV, weighted = false false false; time = 0.4 min
# Rep = 3; pX = 0.01; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 3; pX = 0.01; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 3; pX = 0.01; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 3; pX = 0.01; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 3; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 3; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 3; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 3; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 3; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 3; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 3; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.28 min
# Rep = 3; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 3; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 3; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 3; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 3; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 3; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.27 min
# Rep = 3; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 3; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 3; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 3; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 3; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 3; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 3; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 3; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 3; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 3; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.31 min
# Rep = 3; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 3; pX = 1.0; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 3; pX = 1.0; stratified, CV, weighted = false true false; time = 0.27 min
# Rep = 3; pX = 1.0; stratified, CV, weighted = false false true; time = 0.44 min
# Rep = 3; pX = 1.0; stratified, CV, weighted = false false false; time = 0.45 min
# Rep = 4; pX = 0.01; stratified, CV, weighted = false true true; time = 0.43 min
# Rep = 4; pX = 0.01; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 4; pX = 0.01; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 4; pX = 0.01; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 4; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 4; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 4; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 4; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.28 min
# Rep = 4; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 4; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.35 min
# Rep = 4; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 4; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 4; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 4; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 4; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.32 min
# Rep = 4; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 4; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.27 min
# Rep = 4; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 4; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 4; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 4; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.4 min
# Rep = 4; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 4; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 4; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 4; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.33 min
# Rep = 4; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 4; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 4; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 4; pX = 1.0; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 4; pX = 1.0; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 4; pX = 1.0; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 4; pX = 1.0; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 5; pX = 0.01; stratified, CV, weighted = false true true; time = 0.33 min
# Rep = 5; pX = 0.01; stratified, CV, weighted = false true false; time = 0.27 min
# Rep = 5; pX = 0.01; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 5; pX = 0.01; stratified, CV, weighted = false false false; time = 0.28 min
# Rep = 5; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 5; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 5; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.26 min
# Rep = 5; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 5; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 5; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 5; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.44 min
# Rep = 5; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 5; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.32 min
# Rep = 5; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 5; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.5 min
# Rep = 5; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 5; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 5; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.28 min
# Rep = 5; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 5; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 5; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.5 min
# Rep = 5; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 5; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 5; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.44 min
# Rep = 5; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.5 min
# Rep = 5; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 5; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 5; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 5; pX = 1.0; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 5; pX = 1.0; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 5; pX = 1.0; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 5; pX = 1.0; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 6; pX = 0.01; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 6; pX = 0.01; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 6; pX = 0.01; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 6; pX = 0.01; stratified, CV, weighted = false false false; time = 0.25 min
# Rep = 6; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 6; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.3 min
# Rep = 6; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 6; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 6; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 6; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.25 min
# Rep = 6; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.31 min
# Rep = 6; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 6; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 6; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 6; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 6; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 6; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.26 min
# Rep = 6; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.24 min
# Rep = 6; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 6; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.37 min
# Rep = 6; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.47 min
# Rep = 6; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 6; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 6; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.4 min
# Rep = 6; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 6; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 6; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 6; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 6; pX = 1.0; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 6; pX = 1.0; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 6; pX = 1.0; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 6; pX = 1.0; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 7; pX = 0.01; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 7; pX = 0.01; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 7; pX = 0.01; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 7; pX = 0.01; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 7; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 7; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.41 min
# Rep = 7; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 7; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 7; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 7; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.27 min
# Rep = 7; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.31 min
# Rep = 7; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.37 min
# Rep = 7; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 7; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 7; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 7; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.25 min
# Rep = 7; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 7; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 7; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 7; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 7; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.47 min
# Rep = 7; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.26 min
# Rep = 7; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 7; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 7; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 7; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 7; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 7; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 7; pX = 1.0; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 7; pX = 1.0; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 7; pX = 1.0; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 7; pX = 1.0; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 8; pX = 0.01; stratified, CV, weighted = false true true; time = 0.39 min
# Rep = 8; pX = 0.01; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 8; pX = 0.01; stratified, CV, weighted = false false true; time = 0.48 min
# Rep = 8; pX = 0.01; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 8; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 8; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 8; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 8; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 8; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 8; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 8; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 8; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 8; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 8; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 8; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.32 min
# Rep = 8; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 8; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.46 min
# Rep = 8; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 8; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 8; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 8; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.4 min
# Rep = 8; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 8; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 8; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 8; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 8; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.35 min
# Rep = 8; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.3 min
# Rep = 8; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 8; pX = 1.0; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 8; pX = 1.0; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 8; pX = 1.0; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 8; pX = 1.0; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 9; pX = 0.01; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 9; pX = 0.01; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 9; pX = 0.01; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 9; pX = 0.01; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 9; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 9; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.41 min
# Rep = 9; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 9; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 9; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 9; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 9; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 9; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 9; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.44 min
# Rep = 9; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 9; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 9; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.37 min
# Rep = 9; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 9; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 9; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 9; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 9; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 9; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.35 min
# Rep = 9; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 9; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 9; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 9; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 9; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.48 min
# Rep = 9; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 9; pX = 1.0; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 9; pX = 1.0; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 9; pX = 1.0; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 9; pX = 1.0; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 10; pX = 0.01; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 10; pX = 0.01; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 10; pX = 0.01; stratified, CV, weighted = false false true; time = 0.3 min
# Rep = 10; pX = 0.01; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 10; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 10; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.3 min
# Rep = 10; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 10; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 10; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 10; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 10; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 10; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 10; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.43 min
# Rep = 10; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 10; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.33 min
# Rep = 10; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 10; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 10; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 10; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 10; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 10; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 10; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.25 min
# Rep = 10; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.28 min
# Rep = 10; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 10; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.34 min
# Rep = 10; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 10; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 10; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 10; pX = 1.0; stratified, CV, weighted = false true true; time = 0.49 min
# Rep = 10; pX = 1.0; stratified, CV, weighted = false true false; time = 0.45 min
# Rep = 10; pX = 1.0; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 10; pX = 1.0; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 11; pX = 0.01; stratified, CV, weighted = false true true; time = 0.24 min
# Rep = 11; pX = 0.01; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 11; pX = 0.01; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 11; pX = 0.01; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 11; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 11; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 11; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 11; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.28 min
# Rep = 11; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 11; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 11; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 11; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 11; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.46 min
# Rep = 11; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 11; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 11; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 11; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 11; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 11; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 11; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.41 min
# Rep = 11; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 11; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 11; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.48 min
# Rep = 11; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 11; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.26 min
# Rep = 11; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.24 min
# Rep = 11; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 11; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 11; pX = 1.0; stratified, CV, weighted = false true true; time = 0.33 min
# Rep = 11; pX = 1.0; stratified, CV, weighted = false true false; time = 0.41 min
# Rep = 11; pX = 1.0; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 11; pX = 1.0; stratified, CV, weighted = false false false; time = 0.45 min
# Rep = 12; pX = 0.01; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 12; pX = 0.01; stratified, CV, weighted = false true false; time = 0.35 min
# Rep = 12; pX = 0.01; stratified, CV, weighted = false false true; time = 0.28 min
# Rep = 12; pX = 0.01; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 12; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 12; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 12; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 12; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 12; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.32 min
# Rep = 12; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 12; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 12; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 12; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 12; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 12; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.48 min
# Rep = 12; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 12; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 12; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 12; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 12; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 12; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 12; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 12; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 12; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 12; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 12; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.41 min
# Rep = 12; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 12; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 12; pX = 1.0; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 12; pX = 1.0; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 12; pX = 1.0; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 12; pX = 1.0; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 13; pX = 0.01; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 13; pX = 0.01; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 13; pX = 0.01; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 13; pX = 0.01; stratified, CV, weighted = false false false; time = 0.37 min
# Rep = 13; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.45 min
# Rep = 13; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 13; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 13; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 13; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.47 min
# Rep = 13; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.27 min
# Rep = 13; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 13; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 13; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 13; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.3 min
# Rep = 13; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 13; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.28 min
# Rep = 13; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 13; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 13; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 13; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 13; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.43 min
# Rep = 13; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 13; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 13; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 13; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.4 min
# Rep = 13; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 13; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 13; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 13; pX = 1.0; stratified, CV, weighted = false true true; time = 0.39 min
# Rep = 13; pX = 1.0; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 13; pX = 1.0; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 13; pX = 1.0; stratified, CV, weighted = false false false; time = 0.44 min
# Rep = 14; pX = 0.01; stratified, CV, weighted = false true true; time = 0.43 min
# Rep = 14; pX = 0.01; stratified, CV, weighted = false true false; time = 0.36 min
# Rep = 14; pX = 0.01; stratified, CV, weighted = false false true; time = 0.27 min
# Rep = 14; pX = 0.01; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 14; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 14; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 14; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 14; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 14; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.42 min
# Rep = 14; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 14; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.4 min
# Rep = 14; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 14; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.48 min
# Rep = 14; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 14; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 14; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 14; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 14; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.3 min
# Rep = 14; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 14; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 14; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.26 min
# Rep = 14; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.25 min
# Rep = 14; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.31 min
# Rep = 14; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 14; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 14; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 14; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.25 min
# Rep = 14; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 14; pX = 1.0; stratified, CV, weighted = false true true; time = 0.39 min
# Rep = 14; pX = 1.0; stratified, CV, weighted = false true false; time = 0.44 min
# Rep = 14; pX = 1.0; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 14; pX = 1.0; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 15; pX = 0.01; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 15; pX = 0.01; stratified, CV, weighted = false true false; time = 0.3 min
# Rep = 15; pX = 0.01; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 15; pX = 0.01; stratified, CV, weighted = false false false; time = 0.39 min
# Rep = 15; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 15; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.28 min
# Rep = 15; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 15; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 15; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 15; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 15; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 15; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 15; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.27 min
# Rep = 15; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.28 min
# Rep = 15; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.29 min
# Rep = 15; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 15; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 15; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 15; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 15; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 15; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.31 min
# Rep = 15; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.26 min
# Rep = 15; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.37 min
# Rep = 15; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 15; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.32 min
# Rep = 15; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.34 min
# Rep = 15; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.44 min
# Rep = 15; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 15; pX = 1.0; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 15; pX = 1.0; stratified, CV, weighted = false true false; time = 0.38 min
# Rep = 15; pX = 1.0; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 15; pX = 1.0; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 16; pX = 0.01; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 16; pX = 0.01; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 16; pX = 0.01; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 16; pX = 0.01; stratified, CV, weighted = false false false; time = 0.27 min
# Rep = 16; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 16; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.28 min
# Rep = 16; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 16; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 16; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.37 min
# Rep = 16; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.42 min
# Rep = 16; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.43 min
# Rep = 16; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 16; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.38 min
# Rep = 16; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 16; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 16; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 16; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 16; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 16; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 16; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.35 min
# Rep = 16; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 16; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.33 min
# Rep = 16; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 16; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.4 min
# Rep = 16; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.49 min
# Rep = 16; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 16; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.42 min
# Rep = 16; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.32 min
# Rep = 16; pX = 1.0; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 16; pX = 1.0; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 16; pX = 1.0; stratified, CV, weighted = false false true; time = 0.46 min
# Rep = 16; pX = 1.0; stratified, CV, weighted = false false false; time = 0.42 min
# Rep = 17; pX = 0.01; stratified, CV, weighted = false true true; time = 0.46 min
# Rep = 17; pX = 0.01; stratified, CV, weighted = false true false; time = 0.41 min
# Rep = 17; pX = 0.01; stratified, CV, weighted = false false true; time = 0.41 min
# ...
# Rep = 45; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 45; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.34 min
# Rep = 45; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 45; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 45; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.41 min
# Rep = 45; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.37 min
# Rep = 45; pX = 1.0; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 45; pX = 1.0; stratified, CV, weighted = false true false; time = 0.39 min
# Rep = 45; pX = 1.0; stratified, CV, weighted = false false true; time = 0.47 min
# Rep = 45; pX = 1.0; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 46; pX = 0.01; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 46; pX = 0.01; stratified, CV, weighted = false true false; time = 0.28 min
# Rep = 46; pX = 0.01; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 46; pX = 0.01; stratified, CV, weighted = false false false; time = 0.24 min
# Rep = 46; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 46; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 46; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.36 min
# Rep = 46; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.36 min
# Rep = 46; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.28 min
# Rep = 46; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.29 min
# Rep = 46; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.35 min
# Rep = 46; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 46; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.46 min
# Rep = 46; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 46; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 46; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 46; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 46; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.31 min
# Rep = 46; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.45 min
# Rep = 46; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.33 min
# Rep = 46; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.49 min
# Rep = 46; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.43 min
# Rep = 46; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.3 min
# Rep = 46; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 46; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.32 min
# Rep = 46; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.25 min
# Rep = 46; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.26 min
# Rep = 46; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.25 min
# Rep = 46; pX = 1.0; stratified, CV, weighted = false true true; time = 0.39 min
# Rep = 46; pX = 1.0; stratified, CV, weighted = false true false; time = 0.4 min
# Rep = 46; pX = 1.0; stratified, CV, weighted = false false true; time = 0.34 min
# Rep = 46; pX = 1.0; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 47; pX = 0.01; stratified, CV, weighted = false true true; time = 0.39 min
# Rep = 47; pX = 0.01; stratified, CV, weighted = false true false; time = 0.37 min
# Rep = 47; pX = 0.01; stratified, CV, weighted = false false true; time = 0.27 min
# Rep = 47; pX = 0.01; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 47; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.27 min
# Rep = 47; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.32 min
# Rep = 47; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.3 min
# Rep = 47; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 47; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.35 min
# Rep = 47; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.35 min
# Rep = 47; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.38 min
# Rep = 47; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.38 min
# Rep = 47; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.29 min
# Rep = 47; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 47; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.26 min
# Rep = 47; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.23 min
# Rep = 47; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.24 min
# Rep = 47; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 47; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.24 min
# Rep = 47; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.23 min
# Rep = 47; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.26 min
# Rep = 47; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.23 min
# Rep = 47; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.24 min
# Rep = 47; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.23 min
# Rep = 47; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.25 min
# Rep = 47; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 47; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.23 min
# Rep = 47; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 47; pX = 1.0; stratified, CV, weighted = false true true; time = 0.25 min
# Rep = 47; pX = 1.0; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 47; pX = 1.0; stratified, CV, weighted = false false true; time = 0.24 min
# Rep = 47; pX = 1.0; stratified, CV, weighted = false false false; time = 0.23 min
# Rep = 48; pX = 0.01; stratified, CV, weighted = false true true; time = 0.22 min
# Rep = 48; pX = 0.01; stratified, CV, weighted = false true false; time = 0.21 min
# Rep = 48; pX = 0.01; stratified, CV, weighted = false false true; time = 0.25 min
# Rep = 48; pX = 0.01; stratified, CV, weighted = false false false; time = 0.22 min
# Rep = 48; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.41 min
# Rep = 48; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.25 min
# Rep = 48; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.26 min
# Rep = 48; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.31 min
# Rep = 48; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 48; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.24 min
# Rep = 48; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.29 min
# Rep = 48; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.26 min
# Rep = 48; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.34 min
# Rep = 48; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.23 min
# Rep = 48; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.23 min
# Rep = 48; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.2 min
# Rep = 48; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.25 min
# Rep = 48; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.23 min
# Rep = 48; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.39 min
# Rep = 48; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.29 min
# Rep = 48; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.3 min
# Rep = 48; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.22 min
# Rep = 48; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.22 min
# Rep = 48; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.2 min
# Rep = 48; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.22 min
# Rep = 48; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.21 min
# Rep = 48; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.22 min
# Rep = 48; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.2 min
# Rep = 48; pX = 1.0; stratified, CV, weighted = false true true; time = 0.22 min
# Rep = 48; pX = 1.0; stratified, CV, weighted = false true false; time = 0.21 min
# Rep = 48; pX = 1.0; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 48; pX = 1.0; stratified, CV, weighted = false false false; time = 0.3 min
# Rep = 49; pX = 0.01; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 49; pX = 0.01; stratified, CV, weighted = false true false; time = 0.21 min
# Rep = 49; pX = 0.01; stratified, CV, weighted = false false true; time = 0.22 min
# Rep = 49; pX = 0.01; stratified, CV, weighted = false false false; time = 0.2 min
# Rep = 49; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.23 min
# Rep = 49; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.2 min
# Rep = 49; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.25 min
# Rep = 49; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.19 min
# Rep = 49; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.23 min
# Rep = 49; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.2 min
# Rep = 49; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.22 min
# Rep = 49; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.19 min
# Rep = 49; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.36 min
# Rep = 49; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.2 min
# Rep = 49; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 49; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 49; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.23 min
# Rep = 49; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.2 min
# Rep = 49; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 49; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 49; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 49; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 49; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.24 min
# Rep = 49; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 49; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 49; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 49; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 49; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 49; pX = 1.0; stratified, CV, weighted = false true true; time = 0.2 min
# Rep = 49; pX = 1.0; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 49; pX = 1.0; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 49; pX = 1.0; stratified, CV, weighted = false false false; time = 0.19 min
# Rep = 50; pX = 0.01; stratified, CV, weighted = false true true; time = 0.2 min
# Rep = 50; pX = 0.01; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.01; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 0.01; stratified, CV, weighted = false false false; time = 0.17 min
# Rep = 50; pX = 0.019306977288832506; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.019306977288832506; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.019306977288832506; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 0.019306977288832506; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 50; pX = 0.0372759372031494; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.0372759372031494; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.0372759372031494; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 0.0372759372031494; stratified, CV, weighted = false false false; time = 0.17 min
# Rep = 50; pX = 0.07196856730011521; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.07196856730011521; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.07196856730011521; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 0.07196856730011521; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 50; pX = 0.13894954943731377; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.13894954943731377; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.13894954943731377; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 0.13894954943731377; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 50; pX = 0.2682695795279726; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.2682695795279726; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.2682695795279726; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 50; pX = 0.2682695795279726; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 50; pX = 0.5179474679231212; stratified, CV, weighted = false true true; time = 0.21 min
# Rep = 50; pX = 0.5179474679231212; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 0.5179474679231212; stratified, CV, weighted = false false true; time = 0.21 min
# Rep = 50; pX = 0.5179474679231212; stratified, CV, weighted = false false false; time = 0.18 min
# Rep = 50; pX = 1.0; stratified, CV, weighted = false true true; time = 0.2 min
# Rep = 50; pX = 1.0; stratified, CV, weighted = false true false; time = 0.19 min
# Rep = 50; pX = 1.0; stratified, CV, weighted = false false true; time = 0.2 min
# Rep = 50; pX = 1.0; stratified, CV, weighted = false false false; time = 0.19 min
#
#  Total time = 539.58 mins

# %% [markdown]
# #### Read data from file and plot:

# %%
stratified = false
cov_dists = ["Laplace", "Gaussian", "uniform"]
subfolder = "scaling_pX"

bts_pX = zeros(length(pX_list), n_reps, 4, length(cov_dists),2)
@showprogress for rep in 1:n_reps
    for (i,pX) in enumerate(pX_list) 
        for CV in [true,false] 
            for weighted in [true,false] 
                for (j,cov_dist) in enumerate(cov_dists)
                    for (k,d) in enumerate([5]) 
                        filename  = "/xtmp/PDMP_data_revision/"*subfolder*"/cov_dist:"*cov_dist*"-pX:"*
                        string(pX)*"-rep:"*string(rep)*"-stratified:"*string(stratified)*
                        "-CV:"*string(CV)*"-weighted:"*string(weighted)*"-d:"*string(d)*".jld"
                        skel, bt = load(filename, "xt_skeleton", "bt_skeleton")
                        bts_pX[i,rep,1+CV+2*weighted,j,k] = bt[end]
                        skel, bt = nothing, nothing
                        gc()
                    end
                end
            end
        end
    end
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:08:16

# %%
size(bts_pX)
# Out:
# (8, 50, 4, 3, 2)

# %%
to_plot = zeros(size(bts_pX,1),2,3)
for i in 1:size(to_plot,1) 
    for j in 1:3
        a, b = bts_pX[i,:,3,j,1]./bts_pX[i,:,1,j,1], bts_pX[i,:,4,j,1]./bts_pX[i,:,2,j,1]
        to_plot[i,1,j] = mean(a[a.<Inf])
        to_plot[i,2,j] = mean(b[b.<Inf])
    end
end

# %%
size(to_plot)
# Out:
# (8, 2, 3)

# %%
k = 1
colours = ["red", "blue", "green"]
for (j,cov_dist) in enumerate(cov_dists)
    plot(pX_list, to_plot[:,1,j], "o-", color=colours[j], 
        label="cov_dist:"cov_dist*"; CV false")
    plot(pX_list, 2*pX_list.*Nobs_list./(1+pX_list.*Nobs_list)./pX_list, "--", color="black")
    plot(pX_list, to_plot[:,2,j], "s-", color=colours[j], 
        label="cov_dist:"cov_dist*"; CV true")
    xlabel("alpha", fontsize=10)
    ylabel("Efficiency gain", fontsize=10)
    grid(true)
    xscale("log")
    xticks(pX_list)
    yscale("log")
end
legend(frameon=false, ncol=3,bbox_to_anchor=(-0.24, 1.2), loc=2);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### Previous stuff:

# %%
maxlag = 1000
acfs_all = []
for i in 1:length(xi_samples)
    acf_xi = []
    for j in 1:length(xi_samples[i])
        a = zeros(size(xi_samples[i][j],1), maxlag)
        for dim in 1:size(xi_samples[i][j],1)
            a[dim,:] = acf(xi_samples[i][j][dim,1:end-1], maxlag)
        end
        push!(acf_xi, a)
    end
    push!(acfs_all, acf_xi)
end

# %%
for j in 1:8 
    print(Int(round(maximum(abs.(sum(acfs_all[1][j],2))))), " || ", 
          Int(round(maximum(abs.(sum(acfs_all[2][j],2))))), " || ", 
          Int(round(maximum(abs.(sum(acfs_all[3][j],2))))), " || ",
          Int(round(maximum(abs.(sum(acfs_all[4][j],2))))), " || ",
          Int(round(maximum(abs.(sum(acfs_all[5][j],2))))), " \n ")
end
# Out:
# BoundsError: attempt to access 0-element Array{Any,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{Any,1}, ::Int64) at ./array.jl:549
#  [2] macro expansion at ./In[14]:2 [inlined]
#  [3] anonymous at ./<missing>:?
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
a = zeros(6,5)
a[1,:] = [511, 899, 971, 974, 971]
a[2,:] = [968, 974, 965, 966, 981] 
a[3,:] = [24, 17, 24, 46, 56]
a[4,:] = [262, 172, 194, 453, 949]
a[5,:] = [326, 913, 958, 974, 979]
a[6,:] = [40, 63, 27, 20, 40];

# %%
labels = ["uniform subsampling \n without control variates",
            "uniform subsampling \n with control variates",
            "weighted subsampling \n without control variates",
            "weighted subsampling \n with control variates",
            "sorted sub-sampling", 
            "hybrid sub-sampling"]
figs_to_plot = [8,6,7,5,4,3]
for (i,j) in enumerate(figs_to_plot)
    plot(Nobs_list, [maximum(abs.(sum(acfs_all[i][j],2))) for i in 1:5], "o-", label=labels[i]);
end
yscale("log")
xscale("log")
grid(true)
legend(bbox_to_anchor=(1.03, 1), loc=2, borderaxespad=0.0, ncol=1, fontsize=9)
xlabel("Number of observations", fontsize=10)
ylabel("Integrated auto-correlation time", fontsize=10)
title("Mixing time of slowest component", fontsize=11)
# savefig("plots/IACTs_scaling.pdf", format="pdf", dpi=10000, bbox_inches="tight")
# Out:
# UndefVarError: acfs_all not defined
#
# Stacktrace:
#  [1] collect(::Base.Generator{UnitRange{Int64},##243#244}) at ./array.jl:470
#  [2] macro expansion at ./In[3]:9 [inlined]
#  [3] anonymous at ./<missing>:?
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
fig = figure("pyplot_subplot_mixed", figsize=(6,3))
Nobs_list = [1000, 5000, 10_000, 20_000, 50_000] 
labels = ["uniform sub-sampling \n without control variates",
            "uniform sub-sampling \n with control variates",
            "importance sub-sampling \n without control variates",
            "importance sub-sampling \n with control variates",
            "stratified sub-sampling", 
            "hybrid sub-sampling"]

for i in 1:6
    plot(Nobs_list, a[i,:], "o-", label=labels[i]);
end
yscale("log")
xscale("log")
grid(true)
legend(bbox_to_anchor=(1.03, 1), loc=2, borderaxespad=0.0, ncol=1, fontsize=9)
xlabel("Number of observations", fontsize=10)
ylabel("Integrated auto-correlation time", fontsize=10)
title("Mixing time of slowest component", fontsize=11);
savefig("plots/IACTs_scaling.pdf", format="pdf", dpi=10000, bbox_inches="tight")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x300 with 1 Axes>)
